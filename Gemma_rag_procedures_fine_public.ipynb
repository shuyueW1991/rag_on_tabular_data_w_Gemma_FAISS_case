# %% [markdown]
# # Retrieval Augmented Generation (RAG) using FAISS vector database and Gemma never-empty structured data retrieval.

# %% [markdown]
# This repos owes too much to [jaydeepthik/Gemma-RAG](https://github.com/jaydeepthik/Gemma-RAG/blob/main/Gemma_rag_movies.ipynb).

# %% [markdown]
# First and foremost, pip install the necessary things.

# %%
# !pip install  accelerate bitsandbytes transformers sentence-transformers datasets langchain  matplotlib

# %% [markdown]
# As for faiss-gpu installation, please go to their official documentation where they recommend conda install fashion.

# %% [markdown]
# You can also see the `environment.yml` in the repo, which is the conda export from my own environment. Feel free to be my guest.

# %% [markdown]
# Now let's begin. We introduce a json file as our dataset. Note it has been anonymzied by the `anonymizer.py` in the repo.

# %%
from datasets import load_dataset
import pandas as pd
from tqdm.notebook import tqdm


dataset_df = pd.read_json("result_anonymized.json")
main_dataset_df = dataset_df[["id", "OrderID", "CardID", "CardNo", "OrderCode", "RouteNo", "RouteName", "RatedHour", "DeviceCode", "MachiningDevice", "MachiningDesc", "ClampingMethod", "UsedTools", "SpindleSpeed", "CuttingSpeed", "FeedRate", "CuttingDepth", "CustName", "ProductName"]] ## make test easier.
main_dataset_df.head(15)
# Out:
#                id                               OrderID  \
# 0   746138.173538  SmxnOBuIrjkfrlemkIiDtIQPCbLWUcZhmnOo
# 1   746263.573424  LlCplfwkQROTRBaZfMpcNINAfYNQqkSrwCaC
# 2   749229.348099  wjesXVdTbsDOqoqiUvzjlpEHSYBnstIYSJEX
# 3   749244.781658  hqcFLozynguilkkNucGifbDeRmYkivjrlSiB
# 4   761728.065860  HmkZgTUkOwPZtvIOmvQeRNIPIayTIaYwFzPE
# 5   761644.267951  SRyTInPGkbWQlcolJuGOiAvwsrcabxOzXmte
# 6   740701.729192  YQClnKxeekcIRTsdlsuUGtCItgUccvVRunAz
# 7   740582.839113  GSCBbpGXGuuoFWfuOsilbTOSNVUBOZlofIkI
# 8   740635.727077  UtJeiUpwgyopkKaMEbNNvCvSLjLRZLTYaJca
# 9   740556.268447  cGFxrofcOhAPxKJTBptpNHCBsqCEkGDSOiAv
# 10  740703.499465  TADtIYzHAPmCpdqvFIWBKPSybbIApVayFGRh
# 11  740577.552722  hTzDquMbmwfmNOzjwyNpiVbDFDLxqlaKDBOP
# 12  740697.711423  vIrrJQnzBvZkdIKzKHqtkUVirUBnutcTIUxB
# 13  760447.149857  RJflGFGhDdtiGjTGzlwVsZaFTyqIZJLCrTje
# 14  760513.879015  LEExSelCkHxFHLDbifjHEtuQHdGiWmTYthzQ
#
#                                   CardID               CardNo  \
# 0   OpJKVEyqyBvygjSqlLwjMURdagbXeGMmTpNo  iuhJsPKPQbsjbXUmLjI
# 1   EmlGBBueHyBkXhyCabUbAxIKvmAMpCRfeRig  losOLMpiBHlntZlmKZr
# 2   wAhUjaczojBFyXusshRqHExXcJRmAEOISsnt  tnfmyycnoOlXbXPZfZK
# 3   DhHQDkOhWMAivrRBqgQiQglPNgpFWfuzgPCF  ctSXvszYPSUPkdMYldB
# 4   NhawkDwhUAqHSxCCRGdXusKvBYeBydKgVPRz  NVQVjVqqgYGqMCGwmIj
# 5   PDIkyuqDPuffSNOtwhVezClRarRvAmucCKRp  gDenXgcpFtuDuUshAdZ
# 6   szoXxrqVRjWmjQegEoAbUMrXSorrzuwmfjoO  VZXhimnNeAXCxMzsNoU
# 7   uEdVwfQMEUPAYODSykUfokXAekNDgtiVvYXN  xfCmSlHULdTmHcaARyv
# 8   khxnlZfyJZxgDGBvXmhVTANvGjhqyzxeFFHQ  jFZwiJHqxItUkztCDum
# 9   RRjIZuhIqIAyubxQhGXPaHHSyvcxZIDzBAiB  kOUbNyJrpKCxqpPwwjY
# 10  lAfKHxHFxzJlHkLWBEtAosSpOtiNdXgatGsn  voakRaKmSJWNiqoSAAw
# 11  TKsOoQnRqKBkYslfTesmcRHXpbDGCOZKLkqj  qJsAgqDdQjAebrujpxl
# 12  iAlfbAAFPAuIKdLCYDWqWyguFzhNPsGDARmM  xAhomagcoqnSPTMbVFT
# 13  MfcFHvYZRSYUhGXKzcbxNypoRHieJdxCVNOZ  gDFwRMgYLmbAXQWgNqo
# 14  pUtlXbGFtIJwvOqZjwQYOxOvulqVKpRusRgd  WoupagEMaFZbGmBSwkU
#
#            OrderCode     RouteNo RouteName    RatedHour   DeviceCode  \
# 0   gRHBfICsHFSdZAIv  -28.111525        sG    71.337674         None
# 1   eIvApiopWxnEyLxT  110.864345       bzT    69.354780         None
# 2   PzySElyTFXcYRyHy   47.288207        mB   264.360936         None
# 3   WfyUoFZtkSnwSjdf  -47.295644       bCp   119.252540         None
# 4   MJRlVaCTUfxmMyVi   12.089209       zVq   192.831837         None
# 5   VlvxilbmvzuXgNEA   88.389511       VPk    26.979096         None
# 6   dvjTRcijdIitOgIv   23.033465        tP   146.127140         None
# 7   RDTkIdtRjIdStjmg   38.800646        WM    66.222113         None
# 8   xGUeRruJnPPDrIZV  113.134469      gTnH  4334.099771         None
# 9   GWAgGhPWreUuffiA   62.431049        ko   -11.707966         None
# 10  VUGfJrBtDAyBrDIT    7.029930       vtj    14.791007         None
# 11  ARxQqDhfPSsaPiAZ   86.020891        kN    44.057795         None
# 12  CZGJasmtTuIENhFh  -18.452169       uQo   -10.644615         None
# 13  DySqbXXJLHIkvhtu   40.805256        VL   -62.694353  uRgAEVCyXTQ
# 14  jKqfDTkmfTbQcmVM  -51.789516        mS   -49.036070         None
#
#             MachiningDevice             MachiningDesc ClampingMethod  \
# 0       BEeVUDiRIgdumoomXVh               trDkjXoVjfi             oE
# 1                       YrO                  KQqdqhQa           None
# 2                 iUtjhhOsF                  CIzDLZvI           None
# 3                       yte           zDsLALRQTUThEOV           None
# 4       EyVflUAyzwfluzzuNPY                      CWzi           None
# 5       shRHaWXdfVAotLGvqVp                      VsUq           None
# 6                     uJRXO     nZVvxnVVfYlBulTCWzWjP           None
# 7                      qeFw    gKbjcRHpxFlTMSbElxnEtQ           None
# 8                      hrqq  GGlQtWsKegAQgbSdPJYWCKov           None
# 9                     uSBKO     DeUofICjwftJnubjbclQU           None
# 10                      ZsZ          efXtNhwhOKXOgPyI           None
# 11                  MOKqLXQ                      feld           None
# 12                      mGo                      PLPL           None
# 13        ReVgdzrcKWWsMXXEp                  OzJcmVSq             hz
# 14  GmVxqutbMWvRHEPCkkWdPPh            ntRKJCgqgoJSLd           None
#
#    UsedTools SpindleSpeed  CuttingSpeed   FeedRate  CuttingDepth  \
# 0      FLaFJ         None           NaN        NaN           NaN
# 1       None         None           NaN        NaN           NaN
# 2       None         None           NaN        NaN           NaN
# 3       None         None           NaN        NaN           NaN
# 4       None         None           NaN        NaN           NaN
# 5       None         None           NaN        NaN           NaN
# 6       None         None           NaN        NaN           NaN
# 7       None         None           NaN        NaN           NaN
# 8       None         None           NaN        NaN           NaN
# 9       None         None           NaN        NaN           NaN
# 10      None         None           NaN        NaN           NaN
# 11      None         None           NaN        NaN           NaN
# 12      None         None           NaN        NaN           NaN
# 13      EXEl          zEm           NaN  20.340123    -20.110539
# 14      None         None           NaN        NaN           NaN
#
#               CustName          ProductName
# 0   KKjturzCJvTzaziuem  PGawvqFpJMaPjneBaaf
# 1   UqEQtsVLpDGSZYaAZg  bNiCsBsmmOedzFpTUKw
# 2   YXNyFScWWZYQGjvSev  LNmvWClnHKgodduYWoa
# 3   shQtBMmyDMQgukDEys  BmHtZRJARJrthZRKvue
# 4   pKzeRGZTovpncYMRxt  tZLXSLCjsJwOSEUpeMk
# 5   pIfminwSMCVMwcGtWY  RYBtUkHzzJZfBDvKlUy
# 6        APERpWRnqePsn                tNDiU
# 7        cZMeoOejBsJgo                nxpcd
# 8        aNRsmFWDWOGKr                Pqskb
# 9        ZdEpHOGUOXogd                kYzGI
# 10       YFTzQBfbkgMij                hEJfu
# 11       MyYeNMfzlKBTj                pNpja
# 12       VJQqqJeOEMLTn                lAxKk
# 13       fuuCSGiTjMEkj                   zq
# 14       vJPwrByzfaChj                   ov

# %% [markdown]
# The following three columns are the typical columns that is usually involved in user's input command. For example, `give me an order like this, but customers name like that, etc.`

# %%
faiss_dataset_df = main_dataset_df[[ "OrderCode", "CustName", "ProductName"]] 
faiss_dataset_df.head(8)
# Out:
#           OrderCode            CustName          ProductName
# 0  gRHBfICsHFSdZAIv  KKjturzCJvTzaziuem  PGawvqFpJMaPjneBaaf
# 1  eIvApiopWxnEyLxT  UqEQtsVLpDGSZYaAZg  bNiCsBsmmOedzFpTUKw
# 2  PzySElyTFXcYRyHy  YXNyFScWWZYQGjvSev  LNmvWClnHKgodduYWoa
# 3  WfyUoFZtkSnwSjdf  shQtBMmyDMQgukDEys  BmHtZRJARJrthZRKvue
# 4  MJRlVaCTUfxmMyVi  pKzeRGZTovpncYMRxt  tZLXSLCjsJwOSEUpeMk
# 5  VlvxilbmvzuXgNEA  pIfminwSMCVMwcGtWY  RYBtUkHzzJZfBDvKlUy
# 6  dvjTRcijdIitOgIv       APERpWRnqePsn                tNDiU
# 7  RDTkIdtRjIdStjmg       cZMeoOejBsJgo                nxpcd

# %%
from langchain_community.document_loaders import DataFrameLoader

#convert DataFrane into Langchain Document format for further processing
loader = DataFrameLoader(main_dataset_df, page_content_column="OrderCode") # in our case, OrderCode is the main index. In this way, if one OrderCode is picked in final search, multiple data bearing that OrderCode value can come up.
dataset_docs = loader.load()

#chunking using embedding model
from langchain.text_splitter import RecursiveCharacterTextSplitter
from transformers import AutoTokenizer

#hierarchy of seperators to be used by text splitter
MARKDOWN_SEPARATORS = [
    "\n#{1,6} ",
    "```\n",
    "\n\\*\\*\\*+\n",
    "\n---+\n",
    "\n___+\n",
    "\n\n",
    "\n",
    " ",
    "",
]


#"thenlper/gte-small" with 512 dimentional embedding is used as embedding model
EMB_MODEL_CKP = "thenlper/gte-small"
#get enbedding_tokenizer
embedding_tokenizer = AutoTokenizer.from_pretrained(EMB_MODEL_CKP)


def split_documents(chunk_size, KB, tokenizer=embedding_tokenizer):
  """
    Split documents into chunks of maximum size `chunk_size` tokens and return a list of documents.
  """
  text_splitter = RecursiveCharacterTextSplitter.from_huggingface_tokenizer(
        embedding_tokenizer, #tokenizer to be used to determine number of tokens
        chunk_size=chunk_size,
        chunk_overlap=int(chunk_size / 10),
        add_start_index=True, # If `True`, includes chunk's start index in metadata
        strip_whitespace=True, # If `True`, strips whitespace from the start and end of every document
        separators=MARKDOWN_SEPARATORS, #use seperators for chunking
    )

  docs_processed = []
  for doc in KB:
      docs_processed += text_splitter.split_documents([doc])

  #remove duplicates
  unique_texts = {}
  docs_processed_unique = []
  for doc in tqdm(docs_processed):
    if doc.page_content not in unique_texts:
      unique_texts[doc.page_content] = True
      docs_processed_unique.append(doc)

  return docs_processed_unique

#split documents
docs_processed_tok = split_documents(512, dataset_docs, EMB_MODEL_CKP)
# Out:
#   0%|          | 0/33738 [00:00<?, ?it/s]

# %% [markdown]
# Building Vector Database using FAISS

# %%
from langchain.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores.utils import DistanceStrategy


embedding_model = HuggingFaceEmbeddings(
    model_name = EMB_MODEL_CKP,
    multi_process = True,
    model_kwargs={"device": "cuda"},
    encode_kwargs={"normalize_embeddings": True},  # set True for cosine similarity
)

#create FAISS indices for approximate nearest neighbour search
KNOWLEDGE_VECTOR_DATABASE = FAISS.from_documents(
    dataset_docs, embedding_model, distance_strategy=DistanceStrategy.COSINE
)

# %%
def get_search_result(query, vector_db):
  """
  given a "query" search for top k "OrderCodes" embedded in vector database
  """
  #get top k documents similar to "query"
  retrieved_docs = vector_db.similarity_search(query=user_query, k=50)
  search_result = ""
  search_result_OrderCodes = []
  for result in retrieved_docs:
      retrieved_OrderCode = result.page_content if result.page_content else "N/A"
      retrieved_CustName = result.metadata['CustName'] if result.metadata['CustName'] else "N/A"
      retrieved_ProductName = result.metadata['ProductName'] if result.metadata['ProductName'] else "N/A"
      search_result += f"OrderCode: {retrieved_OrderCode}, CustName: {retrieved_CustName}, ProductName: {retrieved_ProductName}\n" 
      search_result_OrderCodes.append(retrieved_OrderCode)

  return search_result, search_result_OrderCodes

# %% [markdown]
# Load Gemma

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")


# CPU Enabled uncomment below 👇🏽
# model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it")
# GPU Enabled use below 👇🏽
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it", device_map="auto")

# %% [markdown]
# Use Case

# %%
# Conduct query with retrieval of sources
user_query = "Show me all documents with  'CustName' containing 'asdffdsa' and 'ProductName' containing '7jj7of'?"
retrieved_results, retreived_result_OrderCodes = get_search_result(user_query, KNOWLEDGE_VECTOR_DATABASE)
print('RETRIEVED RESULTS')
retrieved_results
# Out:
# RETRIEVED RESULTS
# 'OrderCode: VfdNjTmNsQzwpFB, CustName: EaERvxboSS, ProductName: FkYU\nOrderCode: rmjYDDQitXDsFqJ, CustName: kXuAFfxQuvVqZ, ProductName: oeRUXlgYYBR\nOrderCode: ttDSoFJfxFQkWfQ, CustName: ZMONpIgFGFgWW, ProductName: szqgnb\nOrderCode: VKNfoPDFsnJGVfA, CustName: sCwydzeajT, ProductName: sOaK\nOrderCode: cUYfSATGwqDlgXj, CustName: ipexUKImYPncD, ProductName: zkaXfICdizk\nOrderCode: FdOfnsFfCQuIcDj, CustName: IIYgONfEKLGyk, ProductName: bpbT\nOrderCode: JCWuQHXdslJdKfJ, CustName: WkqnNWSMVPtFY, ProductName: fI\nOrderCode: rmFeqTkqhYfpgjF, CustName: dNjACoAdalBJs, ProductName: KBYFiOirQTMEOx\nOrderCode: ccJfDXAbeCySodB, CustName: SXKQHuleowYct, ProductName: NoBviU\nOrderCode: OFdjFVckAGHKdBp, CustName: jdhLwlRQnV, ProductName: LtKF\nOrderCode: JFqJxjPSTkbCkDm, CustName: YUWwCZYDFhKMa, ProductName: Yw\nOrderCode: KMJyCufBfcCxohd, CustName: KnzCAyIKKwvfi, ProductName: KAyy\nOrderCode: NfdDFJdCjqnwpSV, CustName: hfyUMFmqlMcvp, ProductName: qyqCN\nOrderCode: rmkMFJwNcqKRvjQ, CustName: RpddJkmwrSpF, ProductName: bD\nOrderCode: DVjclswRVzdYCdF, CustName: BGtproHDYUrlA, ProductName: MInIpHysYh\nOrderCode: cmFJdPtkGvWouDp, CustName: jJPzuDLGtpSQZ, ProductName: GxxP\nOrderCode: jFAdVTnXfnnlQfA, CustName: JGQkrmrpXLVzW, ProductName: KxDPiiyiftWl\nOrderCode: VjDCXsdWxjHDTas, CustName: FnMnWheeptzTN, ProductName: SPeJg\nOrderCode: dLXcdfHwQLjFoqf, CustName: UdDzMPyJmvwUf, ProductName: AJxuFxGRce\nOrderCode: FEDXRNdIGYHqbqj, CustName: lHYMIjasPn, ProductName: lgOy\nOrderCode: fCJdKdmDWexuzkv, CustName: bzlyXVgplE, ProductName: uykE\nOrderCode: kJJqDBbKsFLDfoC, CustName: aqnMHhhpNHLaN, ProductName: Cj\nOrderCode: JnpGcrBieLJHSXF, CustName: HgqpVIkIEFgEw, ProductName: UCNKA\nOrderCode: rwfqLqtXYjqdCbf, CustName: lOxHOlivGRrnR, ProductName: ZGcXBNWqwkmh\nOrderCode: VdcdoZcpfvVmMJl, CustName: uhoRlviaem, ProductName: SoGZ\nOrderCode: mGfjxOCFEosJSlh, CustName: fAtZSszrFZBDN, ProductName: GVT\nOrderCode: ZPjtwoFUXjQGpdF, CustName: HFyLkNVQGC, ProductName: qEqD\nOrderCode: lcSbfjNSJSaFCsnB, CustName: STcUpaQeLbQH, ProductName: soBqvf\nOrderCode: gShAvddQNtmEkjf, CustName: AadWNNfETX, ProductName: NOCqcYC\nOrderCode: VDkhWsJngoWiTmf, CustName: nOrdRPLGCDPJ, ProductName: cfgduHokXTtJg\nOrderCode: JCZfHWDJYDcpvKm, CustName: uIjfdqvqmMvzRzKRgA, ProductName: IK\nOrderCode: MGqktdypJyLJjcF, CustName: dgdqYytnoYkbP, ProductName: DNZL\nOrderCode: SFSJCuFYiDkTryF, CustName: SARTgVXGyaEChymZa, ProductName: wGB\nOrderCode: KmKdfcuXClBfiTs, CustName: TYNERyrUigxmfgcSFXoXIY, ProductName: hJoqiSaCe\nOrderCode: FAvCyCvQNGQkNJd, CustName: HgcyLMHCFsNsZAdwt, ProductName: zBk\nOrderCode: jpFAFiFJDXbQLae, CustName: yaNJACYRUwca, ProductName: JIItI\nOrderCode: PNspqKbDcPztRFJ, CustName: jEiKcAtRsB, ProductName: afIa\nOrderCode: XncPmmfvAvfgpfj, CustName: LjOCOejBPm, ProductName: skXZ\nOrderCode: asbCCgWJydBBFeJ, CustName: dkfNCjIyCZtHm, ProductName: tHGr\nOrderCode: XVTBjRGXlJvPNcF, CustName: lJqRveTrQzGb, ProductName: FLAv\nOrderCode: aVofQOQjrOyQcfb, CustName: osYbTBoWUa, ProductName: cezd\nOrderCode: cFQSqDcrwQpjrIn, CustName: AckrpjoOpG, ProductName: qlQB\nOrderCode: advrfpTggQRdfVj, CustName: KiKNIncsmrNnA, ProductName: rgSV\nOrderCode: dhwPQFJlvlXRDsd, CustName: ehZxCQuckMsQp, ProductName: Xvp\nOrderCode: xfQCbFJMDVDsFlC, CustName: JDyJTUBJNXMmS, ProductName: IwBk\nOrderCode: jDfvxAsfBVjpHQI, CustName: jCtFgwzzXgBFT, ProductName: RDHq\nOrderCode: OxVDVpGVWFJjuYF, CustName: KDTrViElzEkCj, ProductName: la\nOrderCode: DvZvhKrfLquCEcQJf, CustName: IQHnGFYyBinXhv, ProductName: qFdCaJJgOrUdYb\nOrderCode: vjrDZJxlmdCsIFj, CustName: xiKJWhPVnRGRW, ProductName: ryWw\nOrderCode: oNFgdLpqnANLVMJ, CustName: xXiFqWdpUSCEK, ProductName: WltThfCSaJ\n'

# %%
combined_information = f"Answer the following query using the provided context. \n <CONTEXT>:\n{retrieved_results}. \n <QUERY>: {user_query}"

#chat template for gemma model conversation
chat = [
    { "role": "user", "content": combined_information },
]
prompt = tokenizer.apply_chat_template(chat, tokenize=False, add_generation_prompt=True)

# Moving tensors to GPU
input_ids = tokenizer(combined_information, return_tensors="pt").to("cuda")

pipe = pipeline(model=model,
                tokenizer = tokenizer,
                task="text-generation",
                # return_full_text=False,
                return_full_text=True,
                # max_new_tokens=500,
                max_new_tokens=5000,
                do_sample=True,
                temperature=2.1,
                top_k=50,
                top_p=1,
                #repetition_penalty=1.1,
                num_return_sequences=1,
                #add_special_tokens=True,
                )
print(f"Query: {user_query}\n")
print(pipe(prompt)[0]["generated_text"])
# Out:
# Query: Show me all documents with  'CustName' containing 'asdffdsa' and 'ProductName' containing '7jj7of'?
#
# <bos><start_of_turn>user
# Answer the following query using the provided context.
#  <CONTEXT>:
# OrderCode: VfdNjTmNsQzwpFB, CustName: EaERvxboSS, ProductName: FkYU
# OrderCode: rmjYDDQitXDsFqJ, CustName: kXuAFfxQuvVqZ, ProductName: oeRUXlgYYBR
# OrderCode: ttDSoFJfxFQkWfQ, CustName: ZMONpIgFGFgWW, ProductName: szqgnb
# OrderCode: VKNfoPDFsnJGVfA, CustName: sCwydzeajT, ProductName: sOaK
# OrderCode: cUYfSATGwqDlgXj, CustName: ipexUKImYPncD, ProductName: zkaXfICdizk
# OrderCode: FdOfnsFfCQuIcDj, CustName: IIYgONfEKLGyk, ProductName: bpbT
# OrderCode: JCWuQHXdslJdKfJ, CustName: WkqnNWSMVPtFY, ProductName: fI
# OrderCode: rmFeqTkqhYfpgjF, CustName: dNjACoAdalBJs, ProductName: KBYFiOirQTMEOx
# OrderCode: ccJfDXAbeCySodB, CustName: SXKQHuleowYct, ProductName: NoBviU
# OrderCode: OFdjFVckAGHKdBp, CustName: jdhLwlRQnV, ProductName: LtKF
# OrderCode: JFqJxjPSTkbCkDm, CustName: YUWwCZYDFhKMa, ProductName: Yw
# OrderCode: KMJyCufBfcCxohd, CustName: KnzCAyIKKwvfi, ProductName: KAyy
# OrderCode: NfdDFJdCjqnwpSV, CustName: hfyUMFmqlMcvp, ProductName: qyqCN
# OrderCode: rmkMFJwNcqKRvjQ, CustName: RpddJkmwrSpF, ProductName: bD
# OrderCode: DVjclswRVzdYCdF, CustName: BGtproHDYUrlA, ProductName: MInIpHysYh
# OrderCode: cmFJdPtkGvWouDp, CustName: jJPzuDLGtpSQZ, ProductName: GxxP
# OrderCode: jFAdVTnXfnnlQfA, CustName: JGQkrmrpXLVzW, ProductName: KxDPiiyiftWl
# OrderCode: VjDCXsdWxjHDTas, CustName: FnMnWheeptzTN, ProductName: SPeJg
# OrderCode: dLXcdfHwQLjFoqf, CustName: UdDzMPyJmvwUf, ProductName: AJxuFxGRce
# OrderCode: FEDXRNdIGYHqbqj, CustName: lHYMIjasPn, ProductName: lgOy
# OrderCode: fCJdKdmDWexuzkv, CustName: bzlyXVgplE, ProductName: uykE
# OrderCode: kJJqDBbKsFLDfoC, CustName: aqnMHhhpNHLaN, ProductName: Cj
# OrderCode: JnpGcrBieLJHSXF, CustName: HgqpVIkIEFgEw, ProductName: UCNKA
# OrderCode: rwfqLqtXYjqdCbf, CustName: lOxHOlivGRrnR, ProductName: ZGcXBNWqwkmh
# OrderCode: VdcdoZcpfvVmMJl, CustName: uhoRlviaem, ProductName: SoGZ
# OrderCode: mGfjxOCFEosJSlh, CustName: fAtZSszrFZBDN, ProductName: GVT
# OrderCode: ZPjtwoFUXjQGpdF, CustName: HFyLkNVQGC, ProductName: qEqD
# OrderCode: lcSbfjNSJSaFCsnB, CustName: STcUpaQeLbQH, ProductName: soBqvf
# OrderCode: gShAvddQNtmEkjf, CustName: AadWNNfETX, ProductName: NOCqcYC
# OrderCode: VDkhWsJngoWiTmf, CustName: nOrdRPLGCDPJ, ProductName: cfgduHokXTtJg
# OrderCode: JCZfHWDJYDcpvKm, CustName: uIjfdqvqmMvzRzKRgA, ProductName: IK
# OrderCode: MGqktdypJyLJjcF, CustName: dgdqYytnoYkbP, ProductName: DNZL
# OrderCode: SFSJCuFYiDkTryF, CustName: SARTgVXGyaEChymZa, ProductName: wGB
# OrderCode: KmKdfcuXClBfiTs, CustName: TYNERyrUigxmfgcSFXoXIY, ProductName: hJoqiSaCe
# OrderCode: FAvCyCvQNGQkNJd, CustName: HgcyLMHCFsNsZAdwt, ProductName: zBk
# OrderCode: jpFAFiFJDXbQLae, CustName: yaNJACYRUwca, ProductName: JIItI
# OrderCode: PNspqKbDcPztRFJ, CustName: jEiKcAtRsB, ProductName: afIa
# OrderCode: XncPmmfvAvfgpfj, CustName: LjOCOejBPm, ProductName: skXZ
# OrderCode: asbCCgWJydBBFeJ, CustName: dkfNCjIyCZtHm, ProductName: tHGr
# OrderCode: XVTBjRGXlJvPNcF, CustName: lJqRveTrQzGb, ProductName: FLAv
# OrderCode: aVofQOQjrOyQcfb, CustName: osYbTBoWUa, ProductName: cezd
# OrderCode: cFQSqDcrwQpjrIn, CustName: AckrpjoOpG, ProductName: qlQB
# OrderCode: advrfpTggQRdfVj, CustName: KiKNIncsmrNnA, ProductName: rgSV
# OrderCode: dhwPQFJlvlXRDsd, CustName: ehZxCQuckMsQp, ProductName: Xvp
# OrderCode: xfQCbFJMDVDsFlC, CustName: JDyJTUBJNXMmS, ProductName: IwBk
# OrderCode: jDfvxAsfBVjpHQI, CustName: jCtFgwzzXgBFT, ProductName: RDHq
# OrderCode: OxVDVpGVWFJjuYF, CustName: KDTrViElzEkCj, ProductName: la
# OrderCode: DvZvhKrfLquCEcQJf, CustName: IQHnGFYyBinXhv, ProductName: qFdCaJJgOrUdYb
# OrderCode: vjrDZJxlmdCsIFj, CustName: xiKJWhPVnRGRW, ProductName: ryWw
# OrderCode: oNFgdLpqnANLVMJ, CustName: xXiFqWdpUSCEK, ProductName: WltThfCSaJ
# .
#  <QUERY>: Show me all documents with  'CustName' containing 'asdffdsa' and 'ProductName' containing '7jj7of'?<end_of_turn>
# <start_of_turn>model
# Based on the context, there no documents mention ` CustName `  ``containing "asdffdsa"   `  and `ProductName` containing "7jj7of"`. Accordingly the result of your  query will be nothing.

# %%
combined_information
# Out:
# "Answer the following query using the provided context. \n <CONTEXT>:\nOrderCode: VfdNjTmNsQzwpFB, CustName: EaERvxboSS, ProductName: FkYU\nOrderCode: rmjYDDQitXDsFqJ, CustName: kXuAFfxQuvVqZ, ProductName: oeRUXlgYYBR\nOrderCode: ttDSoFJfxFQkWfQ, CustName: ZMONpIgFGFgWW, ProductName: szqgnb\nOrderCode: VKNfoPDFsnJGVfA, CustName: sCwydzeajT, ProductName: sOaK\nOrderCode: cUYfSATGwqDlgXj, CustName: ipexUKImYPncD, ProductName: zkaXfICdizk\nOrderCode: FdOfnsFfCQuIcDj, CustName: IIYgONfEKLGyk, ProductName: bpbT\nOrderCode: JCWuQHXdslJdKfJ, CustName: WkqnNWSMVPtFY, ProductName: fI\nOrderCode: rmFeqTkqhYfpgjF, CustName: dNjACoAdalBJs, ProductName: KBYFiOirQTMEOx\nOrderCode: ccJfDXAbeCySodB, CustName: SXKQHuleowYct, ProductName: NoBviU\nOrderCode: OFdjFVckAGHKdBp, CustName: jdhLwlRQnV, ProductName: LtKF\nOrderCode: JFqJxjPSTkbCkDm, CustName: YUWwCZYDFhKMa, ProductName: Yw\nOrderCode: KMJyCufBfcCxohd, CustName: KnzCAyIKKwvfi, ProductName: KAyy\nOrderCode: NfdDFJdCjqnwpSV, CustName: hfyUMFmqlMcvp, ProductName: qyqCN\nOrderCode: rmkMFJwNcqKRvjQ, CustName: RpddJkmwrSpF, ProductName: bD\nOrderCode: DVjclswRVzdYCdF, CustName: BGtproHDYUrlA, ProductName: MInIpHysYh\nOrderCode: cmFJdPtkGvWouDp, CustName: jJPzuDLGtpSQZ, ProductName: GxxP\nOrderCode: jFAdVTnXfnnlQfA, CustName: JGQkrmrpXLVzW, ProductName: KxDPiiyiftWl\nOrderCode: VjDCXsdWxjHDTas, CustName: FnMnWheeptzTN, ProductName: SPeJg\nOrderCode: dLXcdfHwQLjFoqf, CustName: UdDzMPyJmvwUf, ProductName: AJxuFxGRce\nOrderCode: FEDXRNdIGYHqbqj, CustName: lHYMIjasPn, ProductName: lgOy\nOrderCode: fCJdKdmDWexuzkv, CustName: bzlyXVgplE, ProductName: uykE\nOrderCode: kJJqDBbKsFLDfoC, CustName: aqnMHhhpNHLaN, ProductName: Cj\nOrderCode: JnpGcrBieLJHSXF, CustName: HgqpVIkIEFgEw, ProductName: UCNKA\nOrderCode: rwfqLqtXYjqdCbf, CustName: lOxHOlivGRrnR, ProductName: ZGcXBNWqwkmh\nOrderCode: VdcdoZcpfvVmMJl, CustName: uhoRlviaem, ProductName: SoGZ\nOrderCode: mGfjxOCFEosJSlh, CustName: fAtZSszrFZBDN, ProductName: GVT\nOrderCode: ZPjtwoFUXjQGpdF, CustName: HFyLkNVQGC, ProductName: qEqD\nOrderCode: lcSbfjNSJSaFCsnB, CustName: STcUpaQeLbQH, ProductName: soBqvf\nOrderCode: gShAvddQNtmEkjf, CustName: AadWNNfETX, ProductName: NOCqcYC\nOrderCode: VDkhWsJngoWiTmf, CustName: nOrdRPLGCDPJ, ProductName: cfgduHokXTtJg\nOrderCode: JCZfHWDJYDcpvKm, CustName: uIjfdqvqmMvzRzKRgA, ProductName: IK\nOrderCode: MGqktdypJyLJjcF, CustName: dgdqYytnoYkbP, ProductName: DNZL\nOrderCode: SFSJCuFYiDkTryF, CustName: SARTgVXGyaEChymZa, ProductName: wGB\nOrderCode: KmKdfcuXClBfiTs, CustName: TYNERyrUigxmfgcSFXoXIY, ProductName: hJoqiSaCe\nOrderCode: FAvCyCvQNGQkNJd, CustName: HgcyLMHCFsNsZAdwt, ProductName: zBk\nOrderCode: jpFAFiFJDXbQLae, CustName: yaNJACYRUwca, ProductName: JIItI\nOrderCode: PNspqKbDcPztRFJ, CustName: jEiKcAtRsB, ProductName: afIa\nOrderCode: XncPmmfvAvfgpfj, CustName: LjOCOejBPm, ProductName: skXZ\nOrderCode: asbCCgWJydBBFeJ, CustName: dkfNCjIyCZtHm, ProductName: tHGr\nOrderCode: XVTBjRGXlJvPNcF, CustName: lJqRveTrQzGb, ProductName: FLAv\nOrderCode: aVofQOQjrOyQcfb, CustName: osYbTBoWUa, ProductName: cezd\nOrderCode: cFQSqDcrwQpjrIn, CustName: AckrpjoOpG, ProductName: qlQB\nOrderCode: advrfpTggQRdfVj, CustName: KiKNIncsmrNnA, ProductName: rgSV\nOrderCode: dhwPQFJlvlXRDsd, CustName: ehZxCQuckMsQp, ProductName: Xvp\nOrderCode: xfQCbFJMDVDsFlC, CustName: JDyJTUBJNXMmS, ProductName: IwBk\nOrderCode: jDfvxAsfBVjpHQI, CustName: jCtFgwzzXgBFT, ProductName: RDHq\nOrderCode: OxVDVpGVWFJjuYF, CustName: KDTrViElzEkCj, ProductName: la\nOrderCode: DvZvhKrfLquCEcQJf, CustName: IQHnGFYyBinXhv, ProductName: qFdCaJJgOrUdYb\nOrderCode: vjrDZJxlmdCsIFj, CustName: xiKJWhPVnRGRW, ProductName: ryWw\nOrderCode: oNFgdLpqnANLVMJ, CustName: xXiFqWdpUSCEK, ProductName: WltThfCSaJ\n. \n <QUERY>: Show me all documents with  'CustName' containing 'asdffdsa' and 'ProductName' containing '7jj7of'?"

# %%
most_frequent_OrderCode = max(set(retreived_result_OrderCodes), key=retreived_result_OrderCodes.count)

# %%
most_similar_OrderCode = retreived_result_OrderCodes[0]
wanted_filtered_df = main_dataset_df[main_dataset_df['OrderCode'] == most_similar_OrderCode]
wanted_filtered_df
# Out:
#                  id                               OrderID  \
# 2822  671432.928126  cKUlORAWQFZHQNfqEfoaeyZGhlhyGuYqLMrs
#
#                                     CardID               CardNo  \
# 2822  nQfplJxzhnmuXihkgoOamYDeuHLLIsGbERZR  CnciRUTImJlspKUAleL
#
#             OrderCode     RouteNo RouteName   RatedHour DeviceCode  \
# 2822  VfdNjTmNsQzwpFB  174.823396        bm  110.628347       None
#
#      MachiningDevice MachiningDesc ClampingMethod UsedTools SpindleSpeed  \
# 2822            None  ExpFLksePRGR           None      None         None
#
#       CuttingSpeed  FeedRate  CuttingDepth    CustName ProductName
# 2822           NaN       NaN           NaN  EaERvxboSS        FkYU

# %% [markdown]
# In an un-anonymous real json file, the `wanted_filtered_df` usually comes with multiple lines.
